# %%
#%matplotlib widget

# %%
import non_transiting

# %%
target = 9139163
nphase=100
phase_model = np.linspace(0, 360., nphase)
wavearray = np.array([0.430, 0.890])  # Kepler bandpass in micron
planetarymasssini = 11.4  # Earth mass, from RV fit
planetarymasssini = planetarymasssini * 0.00314558  # conversion into Jupiter mass -> not used in the mode right now
effectivetemperature = 6358
stellarmass = 1.390
stellarradius = 1.558
period=0.60474
planetaryradius=0.2  
albedo=0.8
redistribution=1e-3
inclination=30
cloud_offset=0
nlon, nlat = 90, 30

# %%
punto_system = non_transiting.model.ExoplanetarySystem_phaseoffset(orbitalperiod=period,
                                                                  effectivetemperature=effectivetemperature,
                                                                  stellarmass=stellarmass,
                                                                  stellarradius=stellarradius,
                                                                  planetaryradius=planetaryradius,
                                                                  planetarymass=planetarymasssini, inclination=inclination,
                                                                  redistribution=redistribution,
                                                                  albedo=albedo,
                                                                  wavearray=wavearray,
                                                                  phase=phase_model,
                                                                  cloud_offset=cloud_offset,
                                                                  nlon=nlon, nlat=nlat,
                                                                    )
punto_system.compute_flux (reflection_method="global")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 14
#       1 punto_system = non_transiting.model.ExoplanetarySystem_phaseoffset(orbitalperiod=period,
#       2                                                                   effectivetemperature=effectivetemperature,
#       3                                                                   stellarmass=stellarmass,
#    (...)
#      12                                                                   nlon=nlon, nlat=nlat,
#      13                                                                     )
# ---> 14 punto_system.compute_flux (reflection_method="global")
#
# File ~/miniconda3/envs/main-3.11/lib/python3.11/site-packages/non_transiting/model/model.py:736, in ExoplanetarySystem_phaseoffset.compute_flux(self, reflection_method)
#     733 self.compute_longitude_latitude()
#     734 self.check_area()
# --> 736 contrast = self.compute_contrast(reflection_method=reflection_method)
#     738 return contrast
#
# File ~/miniconda3/envs/main-3.11/lib/python3.11/site-packages/non_transiting/model/model.py:678, in ExoplanetarySystem_phaseoffset.compute_contrast(self, reflection_method)
#     675 self.contrast_ppm_refl = np.zeros(nphase)
#     676 self.contrast_ppm_em = np.zeros(nphase)
# --> 678 self.compute_temperature_and_intensity(reflection_method=reflection_method)
#     680 fobs, fobs_refl, fem = self.compute_phasecurve()
#     682 self.read_response_function()
#
# File ~/miniconda3/envs/main-3.11/lib/python3.11/site-packages/non_transiting/model/model.py:400, in ExoplanetarySystem_phaseoffset.compute_temperature_and_intensity(self, reflection_method)
#     397     self.show_atmospheric_temperature_map ()
#     399 # get response function
# --> 400 self.read_response_function()
#     401 # Interpolate response onto same nu-edge grid (self.wavearray is cm^-1)
#     402 if (self.response_nu is not None) and (self.response_vals is not None):
#
# File ~/miniconda3/envs/main-3.11/lib/python3.11/site-packages/non_transiting/model/model.py:152, in ExoplanetarySystem_phaseoffset.read_response_function(self)
#     150 if self.mission == 'Kepler':
#     151     response_function_file = importlib.resources.files (non_transiting.references) / 'Kepler_Response_Function.txt'
# --> 152     response_fonction_data = np.loadtxt(response_function_file,
#     153                                         skiprows = 8)
#     154     response_function_values = response_fonction_data[:, 1]
#     155     response_function_wavelength = response_fonction_data[:, 0] * 10**(-3)  # converted into microns
#
# File ~/miniconda3/envs/main-3.11/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1381, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1378 if isinstance(delimiter, bytes):
#    1379     delimiter = delimiter.decode('latin1')
# -> 1381 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382             converters=converters, skiplines=skiprows, usecols=usecols,
#    1383             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1384             max_rows=max_rows, quote=quotechar)
#    1386 return arr
#
# File ~/miniconda3/envs/main-3.11/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:997, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     995     fname = os.fspath(fname)
#     996 if isinstance(fname, str):
# --> 997     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     998     if encoding is None:
#     999         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/miniconda3/envs/main-3.11/lib/python3.11/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/envs/main-3.11/lib/python3.11/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /Users/sbreton/miniconda3/envs/main-3.11/lib/python3.11/site-packages/non_transiting/references/Kepler_Response_Function.txt not found.

# %%
fig = punto_system.plot_model ()
fig.tight_layout ()

# %%
fig = punto_system.show_reflection_map ()

# %%
fig = punto_system.show_atmospheric_temperature_map ()
